# %% [raw]
# 1️. What are data structures, and why are they important?
#
# Definition:
# Data structures are organized ways to store, manage, and access data efficiently.
# Importance:
# They improve performance, memory usage, and make data handling logical and easy in programming.
#
# Examples: Lists, Tuples, Dictionaries, Sets.
#
# 2️. Difference between mutable and immutable data types (with examples)
# Type	                     Meaning	             Examples
# Mutable	      Can be changed after creation	        list, dict, set
# Immutable     Cannot be changed after creation	    tuple, str, int
#
# Example:
#
# # Mutable
# a = [1, 2, 3]
# a[0] = 10  # Allowed
#
# # Immutable
# b = (1, 2, 3)
# # b[0] = 10 →  Error
#
# 3️. Differences between Lists and Tuples
# Feature      	List	                Tuple
# Syntax      	[]                     	()
# Mutability	   Mutable	             Immutable
# Speed	        Slower	            Faster
# Use case	  Data that changes	    Fixed data
# Example      	[1,2,3]	           (1,2,3)
# 4️. How dictionaries store data
#
# Dictionaries store data as key–value pairs.
#
# Internally, they use a hash table for fast lookup.
# Example:
#
# student = {'name': 'Vivek', 'age': 21}
#
# 5️. Why use a set instead of a list?
#
# Sets automatically remove duplicate elements.
#
# Faster membership checking (in keyword).
# Example:
#
# nums = {1, 2, 3, 3}  # {1, 2, 3}
#
# 6️. What is a string, and how is it different from a list?
#
# A string is a sequence of characters enclosed in quotes (" " or ' ').
# Strings are immutable, while lists are mutable.
#
# Example:
#
# s = "hello"
# # s[0] = 'H'  (Not allowed)
#
# 7️. How do tuples ensure data integrity?
#
# Tuples are immutable, meaning their contents cannot be changed once created.
#
# This prevents accidental modification and maintains data consistency.
#
# 8️. What is a hash table, and how does it relate to dictionaries?
#
# A hash table stores data in key–value form using a hashing function.
# Python dictionaries are implemented using hash tables, allowing O(1) average lookup time.
#
# 9️. Can lists contain different data types?
#
#  Yes.
# Example:
# mixed = [10, "Vivek", 3.14, True]
#
# 10. Why are strings immutable in Python?
#
# For security, efficiency, and thread-safety.
#
# Immutable strings mean one copy can be shared safely between programs.
#
# 11. Advantages of dictionaries over lists
# Feature      	Dictionary                  	List
# Access speed	Fast (O(1)) by key	Slow     (O(n)) by search
# Organization	Key–value mapping	          Sequential
# Use case	   Lookup table                	Ordered collection
#
#
# 12️. How do sets handle duplicate values?
#
# Sets automatically discard duplicates.
#
# s = {1, 2, 2, 3}
# print(s)  # {1, 2, 3}
#
# 13️. Scenario where tuple is preferable over list
#
# When data must not change, e.g., storing coordinates or database records:
#
# location = (19.07, 72.87)  # Latitude, Longitude
#
# 14️. How does the “in” keyword work differently for lists and dictionaries?
# Data Type	Behavior
# List	Checks for element existence
# Dictionary	Checks for key existence only
#
# Example:
#
# d = {'a': 1}
# 'a' in d   # True
# 1 in d     # False
#
# 15️.Can you modify the elements of a tuple? Why or why not?
#
# No.
# Tuples are immutable, so once created, their elements cannot be altered, added, or removed.
#
# 16️. What is a nested dictionary? Example.
#
# A dictionary inside another dictionary.
#
# students = {
#   '101': {'name': 'Vivek', 'age': 21},
#   '102': {'name': 'Asha', 'age': 22}
# }
#
#
# Used for hierarchical or structured data like student databases.
#
# 17. Time complexity of accessing elements in a dictionary
#
#  O(1) on average — because dictionaries use hash tables for direct key lookup.
#
# 18️. When are lists preferred over dictionaries?
#
# When order matters.
#
# When you only need simple sequences, not key-value pairs.
#
# When you often index by position.
#
# 19. Why are dictionaries considered unordered (in older versions)?
#
# Before Python 3.7, dictionaries didn’t maintain insertion order.
#
# Though now they do, conceptually keys are stored by hash, not by index.
#
# 20. Difference between list and dictionary in data retrieval
# Aspect	List	Dictionary
# Retrieval	By index number	By key
# Syntax	mylist[0]	mydict['key']
# Time complexity	O(n)	O(1) average

# %%
# 1. Create a string with your name and print it
name = "Vivek Varude"
print(name)

# 2. Find the length of the string "Hello World"
print(len("Hello World"))

# 3. Slice the first 3 characters from "Python Programming"
s = "Python Programming"
print(s[:3])

# 4. Convert "hello" to uppercase
print("hello".upper())

# 5. Replace "apple" with "orange" in "I like apple"
text = "I like apple"
print(text.replace("apple", "orange"))

# 6. Create a list with numbers 1 to 5 and print it
numbers = [1, 2, 3, 4, 5]
print(numbers)

# 7. Append 10 to the list [1, 2, 3, 4]
lst = [1, 2, 3, 4]
lst.append(10)
print(lst)

# 8. Remove 3 from the list [1, 2, 3, 4, 5]
lst2 = [1, 2, 3, 4, 5]
lst2.remove(3)
print(lst2)

# 9. Access the second element in ['a', 'b', 'c', 'd']
letters = ['a', 'b', 'c', 'd']
print(letters[1])

# 10. Reverse the list [10, 20, 30, 40, 50]
nums = [10, 20, 30, 40, 50]
nums.reverse()
print(nums)

# 11. Create a tuple with elements 100, 200, 300 and print it
tup = (100, 200, 300)
print(tup)

# 12. Access the second-to-last element of ('red', 'green', 'blue', 'yellow')
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])

# 13. Find the minimum number in (10, 20, 5, 15)
nums = (10, 20, 5, 15)
print(min(nums))

# 14. Find the index of "cat" in ('dog', 'cat', 'rabbit')
animals = ('dog', 'cat', 'rabbit')
print(animals.index("cat"))

# 15. Create a tuple of 3 fruits and check if "kiwi" is in it
fruits = ('apple', 'banana', 'mango')
print("kiwi" in fruits)

# 16. Create a set with elements 'a', 'b', 'c' and print it
my_set = {'a', 'b', 'c'}
print(my_set)

# 17. Clear all elements from {1, 2, 3, 4, 5}
s = {1, 2, 3, 4, 5}
s.clear()
print(s)

# 18. Remove 4 from {1, 2, 3, 4}
s = {1, 2, 3, 4}
s.remove(4)
print(s)

# 19. Find the union of {1, 2, 3} and {3, 4, 5}
set1 = {1, 2, 3}
set2 = {3, 4, 5}
print(set1.union(set2))

# 20. Find the intersection of {1, 2, 3} and {2, 3, 4}
set1 = {1, 2, 3}
set2 = {2, 3, 4}
print(set1.intersection(set2))

# 21. Create a dictionary with keys "name", "age", and "city"
person = {"name": "John", "age": 25, "city": "New York"}
print(person)

# 22. Add "country": "USA" to {'name': 'John', 'age': 25}
d = {'name': 'John', 'age': 25}
d["country"] = "USA"
print(d)

# 23. Access value of key "name" in {'name': 'Alice', 'age': 30}
d = {'name': 'Alice', 'age': 30}
print(d["name"])

# 24. Remove key "age" from {'name': 'Bob', 'age': 22, 'city': 'New York'}
d = {'name': 'Bob', 'age': 22, 'city': 'New York'}
d.pop("age")
print(d)

# 25. Check if "city" exists in {'name': 'Alice', 'city': 'Paris'}
d = {'name': 'Alice', 'city': 'Paris'}
print("city" in d)

# 26. Create a list, a tuple, and a dictionary and print them all
my_list = [1, 2, 3]
my_tuple = ('a', 'b', 'c')
my_dict = {'x': 10, 'y': 20}
print(my_list)
print(my_tuple)
print(my_dict)

# 27. Create a list of 5 random numbers between 1 and 100, sort it
import random
rand_list = random.sample(range(1, 101), 5)
rand_list.sort()
print(rand_list)

# 28. Create a list with strings and print element at index 3
words = ["apple", "banana", "cherry", "date", "fig"]
print(words[3])

# 29. Combine two dictionaries and print result
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
merged = {**dict1, **dict2}
print(merged)

# 30. Convert a list of strings into a set
str_list = ["apple", "banana", "apple", "cherry"]
str_set = set(str_list)
print(str_set)
# Out:
# Vivek Varude
# 11
# Pyt
# HELLO
# I like orange
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 10]
# [1, 2, 4, 5]
# b
# [50, 40, 30, 20, 10]
# (100, 200, 300)
# blue
# 5
# 1
# False
# {'a', 'b', 'c'}
# set()
# {1, 2, 3}
# {1, 2, 3, 4, 5}
# {2, 3}
# {'name': 'John', 'age': 25, 'city': 'New York'}
# {'name': 'John', 'age': 25, 'country': 'USA'}
# Alice
# {'name': 'Bob', 'city': 'New York'}
# True
# [1, 2, 3]
# ('a', 'b', 'c')
# {'x': 10, 'y': 20}
# [2, 27, 38, 88, 89]
# date
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'cherry', 'banana', 'apple'}
